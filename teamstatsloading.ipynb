# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.espn.com/nfl/stats/team/_/season/2022/seasontype/2'

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <!-- ESPNFITT | b3ac7c253c4c | 6462803 | ab005ddc | Wed, 02 Aug 2023 02:15:52 GMT -->
# <script async="" src="https://dcf.espn.com/TWDC-DTCI/prod/Bootstrap.js"></script>
# ...

# %%
x = pd.read_html('https://www.teamrankings.com/nfl/stat/points-per-game')

# %%
df = x[0]

# %%
df['Year'] = df.columns[2]

# %%
df = df[['Team', '2022', 'Year']]

# %%
df = df.rename(columns = {'2022': 'PPG'})

# %%
y = pd.read_html('https://www.teamrankings.com/nfl/stat/opponent-points-per-game')

# %%
df2 = y[0]

# %%
df2
# Out:
#     Rank           Team  2022  Last 3  Last 1  Home  Away  2021
# 0      1  San Francisco  17.2    22.0    31.0  15.3  19.4  20.6
# 1      2        NY Jets  18.6    17.7    11.0  19.5  17.8  29.6
# 2      3      Baltimore  18.8    22.3    24.0  17.4  20.0  23.1
# 3      4        Buffalo  19.1    27.0    27.0  20.2  18.0  18.3
# 4      5     Cincinnati  19.6    16.7    23.0  17.9  20.8  21.8
# 5      6         Dallas  19.7    19.7    19.0  19.7  19.8  21.2
# 6      7   Philadelphia  19.8    17.3    38.0  16.6  23.7  23.1
# 7      8     Washington  20.2    22.3     6.0  19.0  21.5  25.5
# 8      9    New Orleans  20.3    10.0    10.0  19.6  20.9  19.7
# 9     10     Pittsburgh  20.4    12.3    14.0  18.3  22.2  24.4
# 10    11    New England  20.4    26.0    35.0  17.9  22.7  19.4
# 11    12      Tennessee  21.1    22.0    20.0  20.6  21.6  20.7
# 12    12         Denver  21.1    35.3    28.0  18.3  23.7  18.9
# 13    14   Jacksonville  21.4    24.3    27.0  20.4  22.2  26.9
# ...

# %%
teamstats = pd.DataFrame()
for i in range(2004, 2023):
    x = pd.read_html('https://www.teamrankings.com/nfl/stat/points-per-game?date=%i-03-15' % (i+1))
    df = x[0]
    df['Year'] = df.columns[2]
    df = df[['Team', str(i), 'Year']]
    df = df.rename(columns = {str(i): 'TeamPPG'})
    x = pd.read_html('https://www.teamrankings.com/nfl/stat/opponent-points-per-game?date=%i-03-15' % (i+1))
    df2 = x[0]
    df2['Year'] = df2.columns[2]
    df2 = df2[['Team', str(i), 'Year']]
    df2 = df2.rename(columns = {str(i): 'teamOPPG'})
    df = pd.merge(df, df2, on = ['Team', 'Year'])
    x = pd.read_html('https://www.teamrankings.com/nfl/stat/yards-per-game?date=%i-03-15' % (i+1))
    df2 = x[0]
    df2['Year'] = df2.columns[2]
    df2 = df2[['Team', str(i), 'Year']]
    df2 = df2.rename(columns = {str(i): 'TeamYPG'})
    df = pd.merge(df, df2, on = ['Team', 'Year'])
    x = pd.read_html('https://www.teamrankings.com/nfl/stat/passing-play-pct?date=%i-03-15' % (i+1))
    df2 = x[0]
    df2['Year'] = df2.columns[2]
    df2 = df2[['Team', str(i), 'Year']]
    df2 = df2.rename(columns = {str(i): 'TeamPassPct'})
    df2['TeamPassPct'] = df2['TeamPassPct'].replace('%', '', regex = True)
    df = pd.merge(df, df2, on = ['Team', 'Year'])
    teamstats = pd.concat([teamstats, df])

# %%
teamstats['Year'] = teamstats['Year'].astype(int)
teamstats['TeamPassPct'] = teamstats['TeamPassPct'].astype(float)

# %%
teamstats = teamstats.reset_index().drop(columns = 'index')

# %%
teamstats
# Out:
#              Team  TeamPPG  Year  teamOPPG  TeamYPG  TeamPassPct
# 0    Indianapolis     31.9  2004      21.9    404.4        56.97
# 1     Kansas City     30.2  2004      27.2    418.3        54.45
# 2     New England     27.5  2004      16.4    352.5        49.02
# 3     LA Chargers     27.2  2004      19.6    350.6        47.90
# 4       Green Bay     25.9  2004      24.2    391.4        57.96
# ..            ...      ...   ...       ...      ...          ...
# 603     Tennessee     17.5  2022      21.1    296.8        50.91
# 604       NY Jets     17.4  2022      18.6    318.2        62.29
# 605       Houston     17.0  2022      24.7    283.5        60.79
# 606  Indianapolis     17.0  2022      25.1    311.6        60.20
# 607        Denver     16.9  2022      21.1    325.1        58.81
#
# [608 rows x 6 columns]

# %%
teamstats.to_csv('teamstats.csv')

# %%
teamdict = dict({'CAR': 'Carolina',
                'ARI': 'Arizona',
                'WAS': 'Washington',
                'CIN': 'Cincinnati',
                'TAM': 'Tampa Bay',
                'STL': 'LA Rams',
                'MIA': 'Miami',
                'IND': 'Indianapolis',
                'PIT': 'Pittsburgh',
                'NYG': 'NY Giants',
                'DAL': 'Dallas',
                'GNB': 'Green Bay',
                'OAK': 'Las Vegas',
                'DEN': 'Denver',
                'SDG': 'LA Chargers',
                'KAN': 'Kansas City',
                'JAX': 'Jacksonville',
                'NOR': 'New Orleans',
                'NWE': 'New England',
                'SEA': 'Seattle',
                'BAL': 'Baltimore',
                'CLE': 'Cleveland',
                'BUF': 'Buffalo',
                'DET': 'Detroit',
                'NYJ': 'New York Jets',
                'PHI': 'Philadelphia',
                'SFO': 'San Francisco',
                'CHI': 'Chicago',
                'TEN': 'Tennessee',
                'MIN': 'Minnesota',
                'HOU': 'Houston',
                'ATL': 'Atlanta',
                'LAR': 'LA Rams',
                'LAC': 'LA Chargers',
                'LVR': 'Las Vegas'})
